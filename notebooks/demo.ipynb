# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# TechGear Customer Service AI Demo\n",
    "\n",
    "This notebook demonstrates our fine-tuned LLM for e-commerce customer service."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "source": [
    "import subprocess\n",
    "\n",
    "def query_assistant(prompt: str) -> str:\n",
    "    \"\"\"Query the Ollama model with a prompt.\"\"\"\n",
    "    cmd = [\"ollama\", \"run\", \"techgear\", prompt]\n",
    "    result = subprocess.run(cmd, capture_output=True, text=True)\n",
    "    return result.stdout.strip()"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Example 1: Product Information"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "source": [
    "query = \"What laptops do you have under $1000?\"\n",
    "response = query_assistant(query)\n",
    "print(f\"Q: {query}\\nA: {response}\")"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Example 2: Return Policy"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "source": [
    "query = \"I want to return an opened laptop after 20 days. Is this possible?\"\n",
    "response = query_assistant(query)\n",
    "print(f\"Q: {query}\\nA: {response}\")"
   ]
  }
 ]
}
